# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaCedillo/Actividad3-ValoresAtipicos/blob/main/Actividad3_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from google.colab import files
files.upload()

# %% [markdown]
# Gastos y costos 20-23.xlsx

# %% [markdown]
# #2020

# %%
df_20 = pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2020', skiprows = 5)
df_20
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Eliminar columna de FECHA
df_2020 = df_20.drop(['FECHA'], axis= 1)

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FOLIO        3153 non-null   object
#  1   UUID         3342 non-null   object
#  2   RFC          3342 non-null   object
#  3   PROVEEDOR    3342 non-null   object
#  4   TIPO GASTO   3342 non-null   object
#  5   GASTO        840 non-null    object
#  6   DESCRIPCION  3342 non-null   object
#  7   TC           2951 non-null   float64
#  8   IMPORTE      3308 non-null   float64
#  9   IVA          3074 non-null   float64
#  10  RET ISR      3342 non-null   float64
#  11  RET IVA      3342 non-null   float64
#  12  TOTAL MX     3342 non-null   float64
#  13  TOTAL SAT    3342 non-null   float64
#  14  TIPO         3341 non-null   object
#  15  STATUS       3342 non-null   object
#  16  POLIZA       21 non-null     object
#  17  Columna1     3342 non-null   float64
# ...

# %%
cuantitativas_20 = df_2020.iloc[ : ,[7,8,9,10,11,12,13,17]]
cualitativas_20 = df_2020.iloc[ :, [0,1,2,3,4,5,6,14,15,16]]

# %%
cuantitativas = cuantitativas_20.fillna(method='bfill')
cualitativas = cualitativas_20.fillna(method='bfill')

# %%
valores_n = cuantitativas.isnull().sum()
print('Cuantitativas: ',valores_n)
valores = cualitativas.isnull().sum()
print('\nCualitativas: ',valores)
# Out:
# Cuantitativas:  TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# Columna1     0
# dtype: int64
#
# Cualitativas:  FOLIO             0
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO             0
# DESCRIPCION       0
# TIPO              0
# STATUS            0
# POLIZA         2898
# dtype: int64

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas.plot(kind='box', vert=False)
plt.title('Valores atipicos del DataFrame')
plt.show()

# %%
y = cuantitativas
perc25 = y.quantile(0.25)
perc75 = y.quantile(0.75)
iqr = perc75 - perc25

lim_sup_20 = perc75 + 1.5*iqr
lim_inf_20 = perc25 - 1.5*iqr

print('Limite superior permitido: ', lim_sup_20)
print('\nLimite inferior permitido: ', lim_inf_20)

#Encontrar Outliers
outliers_20 = cuantitativas[(y>lim_sup_20)|(y<lim_inf_20)]
print('\n',outliers_20)
# Out:
# Limite superior permitido:  TC              1.00000
# IMPORTE      6976.21375
# IVA          1170.77250
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX     7983.17750
# TOTAL SAT    8269.28375
# Columna1        0.00000
# dtype: float64
#
# Limite inferior permitido:  TC              1.00000
# IMPORTE     -4160.35625
# IVA          -687.92750
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX    -4783.14250
# TOTAL SAT   -4832.96625
# Columna1        0.00000
# dtype: float64
#
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0    NaN       NaN  2248.28      NaN      NaN       NaN   16300.00  14051.72
# 1    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 2    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3    NaN  10694.25  1711.08      NaN      NaN  12405.33   12405.33       NaN
# 4    NaN       NaN  5131.03      NaN      NaN       NaN        NaN       NaN
# ...

# %%
#Outliers nulos en el dataframe

cuantitativas2 = cuantitativas[(y<=lim_sup_20)&(y>=lim_inf_20)]
cuantitativas2
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0     0.00     NaN      0.0      0.0   2248.28        NaN       NaN
# 1     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 2     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 3     1.0      NaN     NaN      0.0      0.0       NaN        NaN       0.0
# 4     1.0     0.00     NaN      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3337  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3338  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3339  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3340  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3341  1.0      NaN    0.00      0.0      0.0       NaN        NaN       0.0
#
# [3342 rows x 8 columns]

# %%
cuantitativas3 = cuantitativas2.copy()
cuantitativas3 = cuantitativas3.fillna(round(cuantitativas2.mean(),1))
cuantitativas3
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0     0.00  187.40      0.0      0.0   2248.28    1333.00       0.0
# 1     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 2     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 3     1.0  1093.80  187.40      0.0      0.0   1239.10    1333.00       0.0
# 4     1.0     0.00  187.40      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3337  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3338  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3339  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3340  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3341  1.0  1093.80    0.00      0.0      0.0   1239.10    1333.00       0.0
#
# [3342 rows x 8 columns]

# %%
fecha = df_20['FECHA']
datos_limpios_20 = pd.concat([fecha,cuantitativas3,cualitativas], axis=1)
datos_limpios_20
# Out:
#           FECHA   TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  \
# 0    2020-01-01  1.0     0.00  187.40      0.0      0.0   2248.28    1333.00
# 1    2020-01-01  1.0   490.00   78.40      0.0      0.0    568.40     568.40
# 2    2020-01-01  1.0   195.00   31.20      0.0      0.0    226.20     226.20
# 3    2020-01-01  1.0  1093.80  187.40      0.0      0.0   1239.10    1333.00
# 4    2020-01-01  1.0     0.00  187.40      0.0      0.0      0.00       0.00
# ...         ...  ...      ...     ...      ...      ...       ...        ...
# 3337 2020-12-01  1.0   129.79   20.21      0.0      0.0    150.00     150.00
# 3338 2020-12-01  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37
# 3339 2020-12-01  1.0   163.79   26.21      0.0      0.0    190.00     190.00
# 3340 2020-12-01  1.0     0.00    0.00      0.0      0.0      0.00       0.00
# 3341 2020-12-01  1.0  1093.80    0.00      0.0      0.0   1239.10    1333.00
#
# ...

# %%
nulos = datos_limpios_20.isnull().sum()
nulos
# Out:
# FECHA             0
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# Columna1          0
# FOLIO             0
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO             0
# DESCRIPCION       0
# TIPO              0
# STATUS            0
# POLIZA         2898
# dtype: int64

# %% [markdown]
# #2021

# %%
df_21 = pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2021', skiprows=3)

# %%
#Eliminar columna de FECHA
df_2021 = df_21.drop(['FECHA'], axis= 1)
df_2021
# Out:
#                        FOLIO                                  UUID  \
# 0     0001010100750847116902  71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B
# 1     0001010100752163714102  B8AEDE83-CC76-404C-A611-6B5A87BA561F
# 2                      19788  19B9B2C2-DF58-E24D-B43A-3FC4D5A929E7
# 3                     211781  EAB26414-DD9A-4E8F-9F5C-05FE24D98E48
# 4                     211782  C16F79B5-FB35-4BFC-AF84-708B24F500BB
# ...                      ...                                   ...
# 3030                  127043  83F82167-0D14-144E-9D76-045C95F25DDD
# 3031                   11740  B1C60AE0-02BC-4A33-9513-A280F72B5D06
# 3032              1092957089  255F4A25-5753-4208-8F6B-0B59E5AE4741
# 3033                  747826  D8226E4F-9241-44C3-86A4-CDE9BC932528
# 3034                 1227374  41770F35-39EF-41A4-8DF4-EE9586CF4549
#
#                RFC                                          PROVEEDOR  \
# 0     BNM840515VB1                     BANCO NACIONAL DE MEXICO, S.A.
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FOLIO        2888 non-null   object
#  1   UUID         3035 non-null   object
#  2   RFC          3035 non-null   object
#  3   PROVEEDOR    3035 non-null   object
#  4   TIPO GASTO   3035 non-null   object
#  5   DESCRIPCION  3035 non-null   object
#  6   MP           2381 non-null   object
#  7   TC           3035 non-null   float64
#  8   IMPORTE      3035 non-null   float64
#  9   IVA          3035 non-null   float64
#  10  RET ISR      3035 non-null   float64
#  11  RET IVA      3035 non-null   float64
#  12  TOTAL MX     3035 non-null   float64
#  13  TOTAL SAT    3035 non-null   float64
#  14  TIPO         3035 non-null   object
#  15  STATUS       3035 non-null   object
#  16  POLIZA       663 non-null    object
# dtypes: float64(7), object(10)
# memory usage: 403.2+ KB

# %%
cual_21 = df_2021.iloc[:,[0,1,2,3,4,5,6,14,15,16]]
cuan_21 = df_2021.iloc[:,7:14]

# %%
cuan_21 = cuan_21.fillna(method='bfill')
cual_21 = cual_21.fillna(method='bfill')

# %%
valores_n = cuan_21.isnull().sum()
print('Cuantitativas: ',valores_n)
valores = cual_21.isnull().sum()
print('\nCualitativas: ',valores)
# Out:
# Cuantitativas:  TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# dtype: int64
#
# Cualitativas:  FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TIPO           0
# STATUS         0
# POLIZA         6
# dtype: int64

# %%
fig = plt.figure(figsize = (15,8))
cuan_21.plot(kind='box', vert=False)
plt.title('Valores atipicos del DataFrame')
plt.show()

# %%
y = cuan_21
perc25 = y.quantile(0.25)
perc75 = y.quantile(0.75)
iqr = perc75 - perc25

lim_sup_21 = perc75 + 1.5*iqr
lim_inf_21 = perc25 - 1.5*iqr

print('Limite superior permitido: ', lim_sup_21)
print('\nLimite inferior permitido: ', lim_inf_21)

#Encontrar Outliers
outliers_21 = cuan_21[(y>lim_sup_21)|(y<lim_inf_21)]
print('\n',outliers_21)

#Outliers nulos en el dataframe

cuan_21 = cuan_21[(y<=lim_sup_21)&(y>=lim_inf_21)]
print('\n',cuan_21)
# Out:
# Limite superior permitido:  TC               1.0000
# IMPORTE      10127.7125
# IVA           1381.4750
# RET ISR          0.0000
# RET IVA          0.0000
# TOTAL MX     11580.2750
# TOTAL SAT    11456.0225
# dtype: float64
#
# Limite inferior permitido:  TC              1.0000
# IMPORTE     -6076.6275
# IVA          -828.8850
# RET ISR         0.0000
# RET IVA         0.0000
# TOTAL MX    -6948.1650
# TOTAL SAT   -6818.3175
# dtype: float64
#
#        TC   IMPORTE  IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0    NaN       NaN  NaN      NaN      NaN       NaN        NaN
# 1    NaN       NaN  NaN      NaN      NaN       NaN        NaN
# 2    NaN       NaN  NaN      NaN      NaN       NaN        NaN
# 3    NaN       NaN  NaN      NaN      NaN       NaN        NaN
# 4    NaN       NaN  NaN      NaN      NaN       NaN        NaN
# ...   ..       ...  ...      ...      ...       ...        ...
# 3030 NaN       NaN  NaN      NaN      NaN       NaN        NaN
# ...

# %%
cuan_21_2 = cuan_21.copy()
cuan_21_2 = cuan_21_2.fillna(round(cuan_21.mean(),1))
cuan_21_2
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT
# 0     1.0   490.00   78.40      0.0      0.0     568.4      568.4
# 1     1.0   345.00   55.20      0.0      0.0     400.2      400.2
# 2     1.0  3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3     1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4     1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...   ...      ...     ...      ...      ...       ...        ...
# 3030  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3031  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3032  1.0  1699.50  705.58      0.0      0.0    1903.4     1910.9
# 3033  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3034  1.0  1699.50    0.00      0.0      0.0    1903.4     1910.9
#
# [3035 rows x 7 columns]

# %%
fecha = df_21['FECHA']
datos_limpios_21 = pd.concat([fecha,cuan_21_2,cual_21], axis=1)
datos_limpios_21
# Out:
#           FECHA   TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  \
# 0    2021-01-01  1.0   490.00   78.40      0.0      0.0     568.4      568.4
# 1    2021-01-01  1.0   345.00   55.20      0.0      0.0     400.2      400.2
# 2    2021-01-01  1.0  3447.41  551.59      0.0      0.0    3999.0     3999.0
# 3    2021-01-01  1.0  5551.38  888.22      0.0      0.0    6439.6     6439.6
# 4    2021-01-01  1.0  5551.98  888.32      0.0      0.0    6440.3     6440.3
# ...         ...  ...      ...     ...      ...      ...       ...        ...
# 3030 2021-12-01  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3031 2021-12-01  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3032 2021-12-01  1.0  1699.50  705.58      0.0      0.0    1903.4     1910.9
# 3033 2021-12-01  1.0     0.00    0.00      0.0      0.0       0.0        0.0
# 3034 2021-12-01  1.0  1699.50    0.00      0.0      0.0    1903.4     1910.9
#
# ...

# %%
nulos = datos_limpios_21.isnull().sum()
nulos
# Out:
# FECHA          0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# DESCRIPCION    0
# MP             0
# TIPO           0
# STATUS         0
# POLIZA         6
# dtype: int64

# %% [markdown]
# #2022

# %%
df_22 = pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2022', skiprows=3)
df_22

# %%
df_2022 = df_22.drop(['Fecha'], axis= 1)
df_2022.info()

# %%
df_2022['Otros'] = df_2022['Otros'].fillna(0)

# %%
df_2022['MP'] = df_2022['MP'].fillna(method='ffill')
df_2022['TC'] = df_2022['TC'].fillna(method='ffill')

# %%
cual_22 = df_2022.iloc[:,[0,1,2,3,4,5,6,15,16,17]]
cuan_22 = df_2022.iloc[:,7:15]

cual_22 = cual_22.fillna(method = 'bfill')
cuan_22 = cuan_22.fillna(method = 'bfill')

# %%
valores_n = cuan_22.isnull().sum()
print('Cuantitativas: ',valores_n)
valores = cual_22.isnull().sum()
print('\nCualitativas: ',valores)

# %%
fig = plt.figure(figsize = (15,8))
cuan_22.plot(kind='box', vert=False)
plt.title('Valores atipicos del DataFrame')
plt.show()

# %%
y = cuan_22
perc25 = y.quantile(0.25)
perc75 = y.quantile(0.75)
iqr = perc75 - perc25

lim_sup_22 = perc75 + 1.5*iqr
lim_inf_22 = perc25 - 1.5*iqr

print('Limite superior permitido: ', lim_sup_22)
print('\nLimite inferior permitido: ', lim_inf_22)

#Encontrar Outliers
outliers_22 = cuan_22[(y>lim_sup_22)|(y<lim_inf_22)]
print('\n',outliers_22)

#Outliers nulos en el dataframe

cuan_22 = cuan_22[(y<=lim_sup_22)&(y>=lim_inf_22)]
print('\n',cuan_22)

# %%
cuan_22_2 = cuan_22.copy()
cuan_22_2 = cuan_22_2.fillna(round(cuan_22.mean(),1))
cuan_22_2

# %%
fecha = df_22['Fecha']
datos_limpios_22 = pd.concat([fecha,cuan_22_2,cual_22], axis=1)
datos_limpios_22

# %%
nulos = datos_limpios_21.isnull().sum()
nulos

# %% [markdown]
# #2023

# %%
df_23 = pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name = '2023', skiprows=3)
df_23

# %%
df_2023 = df_23.drop(['Fecha'], axis= 1)
df_2023.info()

# %%
df_2023['Otros'] = df_2023['Otros'].fillna(0)
df_2023['MP'] = df_2023['MP'].fillna(method='ffill')

# %%
cual_23 = df_2023.iloc[:,[0,1,2,3,4,5,6,16,17,18]]
cuan_23 = df_2023.iloc[:,7:16]

cual_23 = cual_23.fillna(method = 'bfill')
cuan_23 = cuan_23.fillna(method = 'bfill')

# %%
valores_n = cuan_23.isnull().sum()
print('Cuantitativas: ',valores_n)
valores = cual_23.isnull().sum()
print('\nCualitativas: ',valores)

# %%
fig = plt.figure(figsize = (15,8))
cuan_23.plot(kind='box', vert=False)
plt.title('Valores atipicos del DataFrame')
plt.show()

# %%
y = cuan_23
perc25 = y.quantile(0.25)
perc75 = y.quantile(0.75)
iqr = perc75 - perc25

lim_sup_23 = perc75 + 1.5*iqr
lim_inf_23 = perc25 - 1.5*iqr

print('Limite superior permitido: ', lim_sup_23)
print('\nLimite inferior permitido: ', lim_inf_23)

#Encontrar Outliers
outliers_23 = cuan_23[(y>lim_sup_23)|(y<lim_inf_23)]
print('\n',outliers_23)

#Outliers nulos en el dataframe

cuan_23 = cuan_23[(y<=lim_sup_23)&(y>=lim_inf_23)]
print('\n',cuan_23)

# %%
cuan_23_2 = cuan_23.copy()
cuan_23_2 = cuan_23_2.fillna(round(cuan_23.mean(),1))
cuan_23_2

# %%
fecha = df_23['Fecha']
datos_limpios_23 = pd.concat([fecha,cuan_23_2,cual_23], axis=1)
datos_limpios_23

# %%
nulos = datos_limpios_23.isnull().sum()
nulos

# %%
datos_limpios_21.to_csv('datos_limpios_21.csv')
from google.colab import files
files.download('datos_limpios_21.csv')

# %%
datos_limpios_22.to_csv('datos_limpios_22.csv')
from google.colab import files
files.download('datos_limpios_22.csv')

datos_limpios_23.to_csv('datos_limpios_23.csv')
from google.colab import files
files.download('datos_limpios_23.csv')

datos_limpios_20.to_csv('datos_limpios_20.csv')
from google.colab import files
files.download('datos_limpios_20.csv')
